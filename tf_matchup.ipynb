# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('P503_5.ATAC.peaks.TF.info.txt', "\t")
df
# Out:
# /Users/sergiomares/miniconda3/envs/tf/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3369: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
#   exec(code_obj, self.user_global_ns, self.user_ns)
#          Chr        c1        c2  chr0     tf_c1     tf_c2          tf_name  \
# 0       chr1     79092     79785  chr1     79271     79291   MA0073.1.RREB1
# 1       chr1     79092     79785  chr1     79271     79292  MA0528.1.ZNF263
# 2       chr1     79092     79785  chr1     79273     79293   MA0073.1.RREB1
# 3       chr1     79092     79785  chr1     79275     79295   MA0073.1.RREB1
# 4       chr1     79092     79785  chr1     79324     79341     MA0685.1.SP4
# ...      ...       ...       ...   ...       ...       ...              ...
# 843556  chrY  59032360  59033135  chrY  59032641  59032656  MA0150.2.Nfe2l2
# ...

# %%
Modules = pd.read_csv('LinkageModulePeaks.csv')
Modules
# Out:
#                            Peak    chr      start        end           FDR  \
# 0      chr7:140335570-140336070   chr7  140335570  140336070  3.075460e-27
# 1        chr7:32656120-32656620   chr7   32656120   32656620  3.067850e-26
# 2        chr2:28903844-28904344   chr2   28903844   28904344  3.806770e-26
# 3        chr8:27510037-27510537   chr8   27510037   27510537  6.517310e-26
# 4      chr7:129471198-129471698   chr7  129471198  129471698  1.240630e-25
# ...                         ...    ...        ...        ...           ...
# 29258     chr17:4805026-4805526  chr17    4805026    4805526  8.263630e-10
# 29259   chr14:65183530-65184030  chr14   65183530   65184030  1.705860e-09
# 29260    chr1:36866543-36867043   chr1   36866543   36867043  1.794310e-09
# 29261  chrX:155110699-155111199   chrX  155110699  155111199  2.056350e-09
# 29262   chr17:56406788-56407288  chr17   56406788   56407288  4.615350e-09
#
#                        Genes  Genes_n          Module
# ...
